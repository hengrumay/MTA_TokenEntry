# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#x = [x**2 for x in range(1,100)]
#y = range(1, 100)

# %%
#plt.plot(x, y, 'ro')
#plt.show()

# %%
week1 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160409.txt")
week2 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160416.txt")
week3 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160423.txt")
week4 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160430.txt")
week5 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160507.txt")
week6 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160514.txt")
week7 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160521.txt")
week8 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160528.txt")
week9 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160604.txt")
mtadf = pd.concat([week1, week2, week3, week4, week5, week6, week7, week8, week9])

# %%
week1 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160409.txt")
week2 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160416.txt")

# %%
week1['week_flg'] = 1
week2['week_flg'] = 2

# %%
mtadf = pd.concat([week1, week2], ignore_index=True)

# %%
#mtadf = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160409.txt")
mtadf = mtadf.rename(columns=lambda x: x.strip())#stripping trailing/leading blanks

# %%
mtadf['date_time'] =pd.to_datetime(mtadf['DATE'] + ' ' + mtadf['TIME'],format="%m/%d/%Y %H:%M:%S")
mtadf['DATE'] = pd.to_datetime(mtadf['DATE'], format="%m/%d/%Y")

# %%
mtadf['statline'] = mtadf['STATION'] + ' ' +mtadf['LINENAME']
mtadf = mtadf.drop(axis=1, labels = ['DIVISION', 'DESC']) #drop columns
mtadf.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME       DATE      TIME  ENTRIES  \
# 0  A002  R051  02-00-00   59 ST   NQR456 2016-04-02  00:00:00  5600838
# 1  A002  R051  02-00-00   59 ST   NQR456 2016-04-02  04:00:00  5600863
# 2  A002  R051  02-00-00   59 ST   NQR456 2016-04-02  08:00:00  5600877
# 3  A002  R051  02-00-00   59 ST   NQR456 2016-04-02  12:00:00  5600922
# 4  A002  R051  02-00-00   59 ST   NQR456 2016-04-02  16:00:00  5601172
#
#      EXITS  week_flg           date_time      statline
# 0  1896290         1 2016-04-02 00:00:00  59 ST NQR456
# 1  1896293         1 2016-04-02 04:00:00  59 ST NQR456
# 2  1896313         1 2016-04-02 08:00:00  59 ST NQR456
# 3  1896375         1 2016-04-02 12:00:00  59 ST NQR456
# 4  1896445         1 2016-04-02 16:00:00  59 ST NQR456

# %%
mtadf['dow'] = mtadf['DATE'].apply(datetime.weekday) #have to use apply to iterate over series

# %%
#mtadf.head(1000)

# %%
mtadf= mtadf.sort_values(by=['statline','C/A','UNIT','SCP','date_time'])
mtadf
# Out:
#          C/A  UNIT       SCP    STATION LINENAME       DATE      TIME  \
# 29557   H007  R248  00-00-00       1 AV        L 2016-04-02  00:00:00
# 29558   H007  R248  00-00-00       1 AV        L 2016-04-02  04:00:00
# 29559   H007  R248  00-00-00       1 AV        L 2016-04-02  08:00:00
# 29560   H007  R248  00-00-00       1 AV        L 2016-04-02  12:00:00
# 29561   H007  R248  00-00-00       1 AV        L 2016-04-02  16:00:00
# 29562   H007  R248  00-00-00       1 AV        L 2016-04-02  20:00:00
# 29563   H007  R248  00-00-00       1 AV        L 2016-04-03  00:00:00
# 29564   H007  R248  00-00-00       1 AV        L 2016-04-03  04:00:00
# 29565   H007  R248  00-00-00       1 AV        L 2016-04-03  08:00:00
# 363995        0.0
# 363996        0.0
# 363997        0.0
# 363998        0.0
# 363999        0.0
# 364000        0.0
# 364001        0.0
# 364002        0.0
# 364003        0.0
# 364004        0.0
# 364005        0.0
# 364006        0.0
# 364007        0.0
# 364008        0.0
# 364009        0.0
# 364010        0.0
#
# [387800 rows x 14 columns]

# %%
mtadf2 =mtadf[mtadf['TIME'] != '00:00:00']

# %%
mtadf2
# Out:
#          C/A  UNIT       SCP    STATION LINENAME       DATE      TIME  \
# 29558   H007  R248  00-00-00       1 AV        L 2016-04-02  04:00:00
# 29559   H007  R248  00-00-00       1 AV        L 2016-04-02  08:00:00
# 29560   H007  R248  00-00-00       1 AV        L 2016-04-02  12:00:00
# 29561   H007  R248  00-00-00       1 AV        L 2016-04-02  16:00:00
# 29562   H007  R248  00-00-00       1 AV        L 2016-04-02  20:00:00
# 29564   H007  R248  00-00-00       1 AV        L 2016-04-03  04:00:00
# 29565   H007  R248  00-00-00       1 AV        L 2016-04-03  08:00:00
# 29566   H007  R248  00-00-00       1 AV        L 2016-04-03  12:00:00
# 29567   H007  R248  00-00-00       1 AV        L 2016-04-03  16:00:00
# 29568   H007  R248  00-00-00       1 AV        L 2016-04-03  20:00:00
# 29570   H007  R248  00-00-00       1 AV        L 2016-04-04  04:00:00
# 29571   H007  R248  00-00-00       1 AV        L 2016-04-04  08:00:00
# 29572   H007  R248  00-00-00       1 AV        L 2016-04-04  12:00:00
# 29573   H007  R248  00-00-00       1 AV        L 2016-04-04  16:00:00
# 29574   H007  R248  00-00-00       1 AV        L 2016-04-04  20:00:00
# 29576   H007  R248  00-00-00       1 AV        L 2016-04-05  04:00:00
# 29577   H007  R248  00-00-00       1 AV        L 2016-04-05  08:00:00
# 29578   H007  R248  00-00-00       1 AV        L 2016-04-05  12:00:00
# 29579   H007  R248  00-00-00       1 AV        L 2016-04-05  16:00:00
# 29580   H007  R248  00-00-00       1 AV        L 2016-04-05  20:00:00
# 29582   H007  R248  00-00-00       1 AV        L 2016-04-06  04:00:00
# 29583   H007  R248  00-00-00       1 AV        L 2016-04-06  08:00:00
# 29584   H007  R248  00-00-00       1 AV        L 2016-04-06  12:00:00
# 29585   H007  R248  00-00-00       1 AV        L 2016-04-06  16:00:00
# 29586   H007  R248  00-00-00       1 AV        L 2016-04-06  20:00:00
# 29588   H007  R248  00-00-00       1 AV        L 2016-04-07  04:00:00
# 29589   H007  R248  00-00-00       1 AV        L 2016-04-07  08:00:00
# 29590   H007  R248  00-00-00       1 AV        L 2016-04-07  12:00:00
# 29591   H007  R248  00-00-00       1 AV        L 2016-04-07  16:00:00
# 29592   H007  R248  00-00-00       1 AV        L 2016-04-07  20:00:00
# ...      ...   ...       ...        ...      ...        ...       ...
# 363981  R419  R326  00-05-01  ZEREGA AV        6 2016-04-11  01:00:00
# 363982  R419  R326  00-05-01  ZEREGA AV        6 2016-04-11  05:00:00
# 363983  R419  R326  00-05-01  ZEREGA AV        6 2016-04-11  09:00:00
# 363984  R419  R326  00-05-01  ZEREGA AV        6 2016-04-11  13:00:00
# 363985  R419  R326  00-05-01  ZEREGA AV        6 2016-04-11  17:00:00
# 364007        39        34         2 2016-04-15 09:00:00  ZEREGA AV 6    4
# 364008        39        34         2 2016-04-15 13:00:00  ZEREGA AV 6    4
# 364009        39        34         2 2016-04-15 17:00:00  ZEREGA AV 6    4
# 364010        39        34         2 2016-04-15 21:00:00  ZEREGA AV 6    4
#
#         entrydiff
# 29558       196.0
# 29559       118.0
# 29560       638.0
# 29561       804.0
# 29562       816.0
# 29564       238.0
# 29565        85.0
# 29566       478.0
# 29567       833.0
# 29568       643.0
# 29570        35.0
# 29571       445.0
# 29572       860.0
# 29573      1014.0
# 29574      1063.0
# 29576        40.0
# 29577       487.0
# 29578      1599.0
# 29579      1314.0
# 29580      1012.0
# 29582        60.0
# 29583       434.0
# 29584      1363.0
# 29585      1020.0
# 29586      1317.0
# 29588        53.0
# 29589       454.0
# 29590      1347.0
# 29591      1100.0
# 29592      1222.0
# ...           ...
# 363981        0.0
# 363982        0.0
# 363983        0.0
# 363984        0.0
# 363985        0.0
# 363986        0.0
# 363987        0.0
# 363988        0.0
# 363989        0.0
# 363990        0.0
# 363991        0.0
# 363992        0.0
# 363993        0.0
# 363994        0.0
# 363995        0.0
# 363996        0.0
# 363997        0.0
# 363998        0.0
# 363999        0.0
# 364000        0.0
# 364001        0.0
# 364002        0.0
# 364003        0.0
# 364004        0.0
# 364005        0.0
# 364006        0.0
# 364007        0.0
# 364008        0.0
# 364009        0.0
# 364010        0.0
#
# [354202 rows x 14 columns]

# %%
mtadf2['entrydiff'].describe()
# Out:
# count    3.260310e+05
# mean     3.876159e+05
# std      2.137250e+07
# min      1.000000e+00
# 25%      3.100000e+01
# 50%      1.230000e+02
# 75%      3.140000e+02
# max      2.146684e+09
# Name: entrydiff, dtype: float64

# %%
mtadf2["entrydiff"].quantile(.995)
# Out:
# 458776.64999999932

# %%
mtadf2["entrydiff"].value_counts()
# Out:
#  0.000000e+00    52881
#  1.000000e+00     6151
#  2.000000e+00     4501
#  3.000000e+00     3975
#  4.000000e+00     3695
#  5.000000e+00     3453
#  6.000000e+00     3240
#  7.000000e+00     3173
#  8.000000e+00     3021
#  1.000000e+01     2783
#  9.000000e+00     2754
#  1.100000e+01     2667
#  1.200000e+01     2598
#  1.300000e+01     2385
#  1.500000e+01     2356
#  1.400000e+01     2334
#  1.600000e+01     2302
#  1.700000e+01     2184
#  1.900000e+01     2019
#  1.800000e+01     2001
#  2.000000e+01     1911
#  2.100000e+01     1873
#  2.200000e+01     1806
#  2.300000e+01     1767
#  2.400000e+01     1767
#  2.500000e+01     1647
#  2.600000e+01     1598
#  2.700000e+01     1565
#  2.800000e+01     1513
#  2.900000e+01     1490
#                  ...
#  3.812797e+06        1
# -3.524486e+06        1
# -1.427441e+06        1
#  1.193994e+06        1
# -4.049085e+06        1
# -4.861383e+07        1
#  4.339245e+06        1
# -9.046880e+05        1
# -3.804250e+05        1
#  1.192426e+06        1
#  3.289560e+06        1
# -9.051170e+05        1
# -4.050998e+06        1
#  1.191522e+06        1
#  5.385094e+06        1
#  2.759269e+06        1
# -3.003538e+06        1
# -2.003687e+09        1
# -1.086914e+07        1
#  1.188874e+06        1
#  1.713030e+06        1
#  6.639580e+05        1
# -9.091080e+05        1
#  1.392510e+05        1
# -1.925979e+07        1
# -3.854610e+05        1
#  1.386800e+05        1
#  4.332514e+06        1
#  1.380190e+05        1
#  5.868800e+05        1
# Name: entrydiff, dtype: int64

# %%
mtadf2 = mtadf[mtadf['entrydiff'] < 458777]

# %%
len(mtadf2alt)
# Out:
# 385702

# %%
len(mtadf)
# Out:
# 387800

# %%
mtadf2 = mtadf[mtadf['entrydiff'] > 0]

# %%
mtadf2['entrydiff'].describe()
# Out:
# count    3.260310e+05
# mean     3.876159e+05
# std      2.137250e+07
# min      1.000000e+00
# 25%      3.100000e+01
# 50%      1.230000e+02
# 75%      3.140000e+02
# max      2.146684e+09
# Name: entrydiff, dtype: float64

# %%
mtadf2['entrydiff'].argmin()
# Out:
# 134259

# %%
mtadf.ix[134259]
# Out:
# C/A                         R170
# UNIT                        R191
# SCP                     00-03-00
# STATION                   103 ST
# LINENAME                       1
# DATE         2016-04-07 00:00:00
# TIME                    05:00:00
# ENTRIES                  6893106
# EXITS                    3799456
# week_flg                       1
# date_time    2016-04-07 05:00:00
# statline                103 ST 1
# dow                            3
# entrydiff                      1
# Name: 134259, dtype: object

# %%
mtadf2['entrydiff'].max()
# Out:
# 2146684256.0

# %%
mtadf2.nlargest(5,columns='entrydiff').plot(x= 'statline', y= 'entrydiff',kind='barh')

# %%
mtadf2.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DATE', 'TIME', 'ENTRIES',
#        'EXITS', 'week_flg', 'date_time', 'statline', 'dow', 'entrydiff'],
#       dtype='object')

# %%
mtadf3 = mtadf2.groupby(by=['statline'])['entrydiff'].sum()

# %%
mtadf3
# Out:
# statline
# 1 AV L                        1.745007e+06
# 103 ST 1                      1.405644e+04
# 103 ST 6                      9.157217e+04
# 103 ST BC                     2.380202e+02
# 103 ST-CORONA 7               2.320046e+04
# 104 ST A                      5.405674e+06
# 104 ST JZ                     8.162562e+06
# 110 ST 6                      2.507543e+04
# 111 ST 7                      2.098495e+03
# 111 ST A                      5.957520e+03
# 111 ST J                      9.069946e+03
# 116 ST 23                     1.115224e+04
# 116 ST 6                      2.466188e+04
# 116 ST BC                     2.366446e+06
# 116 ST-COLUMBIA 1             2.392605e+06
# 121 ST JZ                     2.114257e+03
# 125 ST 1                      1.586205e+06
# 125 ST 23                     3.930892e+06
# 125 ST 456                    2.133572e+06
# 125 ST ACBD                   3.389332e+05
# 135 ST 23                     1.886124e+04
# 135 ST BC                     9.647090e+04
# 137 ST CITY COL 1             7.765893e+05
# 138/GRAND CONC 45             3.936927e+06
# 14 ST 123FLM                  1.943890e+05
# 14 ST ACEL                    1.501027e+05
# 14 ST FLM123                  2.059134e+04
# 14 ST-UNION SQ 456LNQR        2.059124e+05
# 14 ST-UNION SQ LNQR456        3.611922e+05
# 145 ST 1                      1.914359e+06
#                                   ...
# THIRTY THIRD ST 1             6.614687e+03
# TIMES SQ-42 ST 1237ACENQRS    1.698387e+06
# TIMES SQ-42 ST ACENQRS1237    6.468964e+02
# TOMPKINSVILLE 1               1.765843e+04
# TREMONT AV BD                 1.495887e+05
# TWENTY THIRD ST 1             2.785426e+03
# UNION ST R                    1.708648e+04
# UTICA AV AC                   9.177272e+04
# V.CORTLANDT PK 1              3.269739e+04
# VAN SICLEN AV 3               1.771043e+03
# VAN SICLEN AV JZ              1.463623e+04
# VAN SICLEN AVE C              1.069733e+04
# VERNON-JACKSON 7              1.807581e+04
# W 4 ST-WASH SQ ABCDEFM        5.050309e+05
# W 8 ST-AQUARIUM FQ            1.171663e+03
# WAKEFIELD/241 2               1.637822e+03
# WALL ST 23                    2.466077e+04
# WALL ST 45                    2.999401e+05
# WEST FARMS SQ 25              8.415390e+05
# WESTCHESTER SQ 6              3.008208e+04
# WHITEHALL S-FRY R1            1.188506e+05
# WHITLOCK AV 6                 4.490475e+05
# WILSON AV L                   1.104356e+04
# WINTHROP ST 25                3.530199e+04
# WOODHAVEN BLVD JZ             3.920149e+05
# WOODHAVEN BLVD MR             5.349122e+04
# WOODLAWN 4                    8.116745e+03
# WORLD TRADE CTR ACE23         2.295007e+04
# YORK ST F                     1.414796e+03
# ZEREGA AV 6                   7.138408e+02
# Name: entrydiff, dtype: float64

# %%
mtadf3.nlargest(15).plot(x= 'statline', y= 'entrydiff',kind='barh')

# %%
mtadf3
# Out:
#                    statline  dow     entrydiff
# 0                    1 AV L    0  3.733417e+02
# 1                    1 AV L    1  3.917583e+02
# 2                    1 AV L    2  4.184250e+02
# 3                    1 AV L    3  4.217833e+02
# 4                    1 AV L    4  4.387750e+02
# 5                    1 AV L    5  1.257367e+07
# 6                    1 AV L    6  2.895000e+02
# 7                  103 ST 1    0  3.671389e+02
# 8                  103 ST 1    1  4.247879e+02
# 9                  103 ST 1    2  3.757067e+02
# 10                 103 ST 1    3  4.024265e+02
# 11                 103 ST 1    4  4.136912e+02
# 12                 103 ST 1    5  9.879281e+04
# 13                 103 ST 1    6  2.436806e+02
# 14                 103 ST 6    0  4.510400e+02
# 15                 103 ST 6    1  4.918333e+02
# 16                 103 ST 6    2  1.230901e+05
# 17                 103 ST 6    3  4.154286e+02
# 18                 103 ST 6    4  3.428667e+02
# 19                 103 ST 6    5  6.307137e+05
# 20                 103 ST 6    6  1.612000e+02
# 21                103 ST BC    0  2.677500e+02
# 22                103 ST BC    1  2.804000e+02
# 23                103 ST BC    2  2.845000e+02
# 24                103 ST BC    3  2.783611e+02
# 25                103 ST BC    4  2.779167e+02
# 26                103 ST BC    5  1.476970e+02
# 27                103 ST BC    6  1.231667e+02
# 28          103 ST-CORONA 7    0  3.742870e+02
# 29          103 ST-CORONA 7    1  3.796481e+02
# ...                     ...  ...           ...
# 3274      WOODHAVEN BLVD MR    5  3.982349e+05
# 3275      WOODHAVEN BLVD MR    6  2.313980e+02
# 3276             WOODLAWN 4    0  2.510000e+02
# 3277             WOODLAWN 4    1  2.617833e+02
# 3278             WOODLAWN 4    2  2.734833e+02
# 3279             WOODLAWN 4    3  2.640167e+02
# 3280             WOODLAWN 4    4  2.595667e+02
# 3281             WOODLAWN 4    5  5.966775e+04
# 3282             WOODLAWN 4    6  1.216170e+02
# 3283  WORLD TRADE CTR ACE23    0  2.415424e+02
# 3284  WORLD TRADE CTR ACE23    1  2.793148e+02
# 3285  WORLD TRADE CTR ACE23    2  2.873211e+02
# 3286  WORLD TRADE CTR ACE23    3  2.846239e+02
# 3287  WORLD TRADE CTR ACE23    4  2.884771e+02
# 3288  WORLD TRADE CTR ACE23    5  1.704959e+05
# 3289  WORLD TRADE CTR ACE23    6  1.251273e+02
# 3290              YORK ST F    0  5.475556e+02
# 3291              YORK ST F    1  5.151944e+02
# 3292              YORK ST F    2  5.882778e+02
# 3293              YORK ST F    3  5.777778e+02
# 3294              YORK ST F    4  5.794167e+02
# 3295              YORK ST F    5  7.015824e+03
# 3296              YORK ST F    6  3.906944e+02
# 3297            ZEREGA AV 6    0  1.146875e+02
# 3298            ZEREGA AV 6    1  1.162917e+02
# 3299            ZEREGA AV 6    2  1.245870e+02
# 3300            ZEREGA AV 6    3  1.195625e+02
# 3301            ZEREGA AV 6    4  1.137917e+02
# 3302            ZEREGA AV 6    5  4.417830e+03
# 3303            ZEREGA AV 6    6  4.275000e+01
#
# [3304 rows x 3 columns]

# %%
plt.figure(figsize=(15,7))
# plt.figure()
# StatFlowDF2.nlargest(15).plot(kind='bar')
#df = StatFlowDS.sort_values(ascending=False)
ax = mtadf2.iloc[:11].plot(kind="barh")
ax.invert_yaxis()

# %%
StatFlowDS = pd.Series(mtadf2[['statline','entrydiff']], name = 'DateValue')
# StatFlowDF2.to_csv('StatFlowDF2.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/pillbug/anaconda3/lib/python3.5/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#    1403                 result = np.empty(len(values), dtype=object)
# -> 1404                 result[:] = values
#    1405             except ValueError:
#
# ValueError: could not broadcast input array from shape (192421,2) into shape (192421)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-b8e68b22f683> in <module>()
# ----> 1 StatFlowDS = pd.Series(mtadf2[['statline','entrydiff']], name = 'DateValue')
#       2 # StatFlowDF2.to_csv('StatFlowDF2.csv')
#
# /Users/pillbug/anaconda3/lib/python3.5/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     225             else:
#     226                 data = _sanitize_array(data, index, dtype, copy,
# --> 227                                        raise_cast_failure=True)
#     228
#     229                 data = SingleBlockManager(data, index, fastpath=True)
#
# /Users/pillbug/anaconda3/lib/python3.5/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    2920             raise Exception('Data must be 1-dimensional')
#    2921         else:
# -> 2922             subarr = _asarray_tuplesafe(data, dtype=dtype)
#    2923
#    2924     # This is to prevent mixed-type Series getting all casted to
#
# /Users/pillbug/anaconda3/lib/python3.5/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#    1405             except ValueError:
#    1406                 # we have a list-of-list
# -> 1407                 result[:] = [tuple(x) for x in values]
#    1408
#    1409     return result
#
# ValueError: cannot copy sequence with size 2 to array axis with dimension 192421

# %%
diff_df['sumentry'] = mtadf.groupby(by=['statline', 'date_time','dow','TIME']).sum().reset_index()

#df.groupby('userid').sum()
#diff_df.rename(columns = {'ENTRIES':'entrydiff', 'EXITS' :'exitdiff'}, inplace = True)
#print(len(diff_df))

# %%
#pd.value_counts(mtadf['UNIT'].values)
len(diff_df)

# %%
mtadf.dtypes

# %%
#import dateutil.parser
#mtadf['date_time'] = mtadf['DATE'].apply(dateutil.parser.parse )
#mtadf

# %%
#mtadf['DATE'] + ' ' + mtadf['TIME']

# %%
mtadf.dtypes

# %%
diff_df = mtadf.groupby(by=['statline', 'date_time','dow','TIME'])[('ENTRIES','EXITS')].sum().diff().reset_index()
diff_df.rename(columns = {'ENTRIES':'entrydiff', 'EXITS' :'exitdiff'}, inplace = True)
print(len(diff_df))
#mtadf.join(diff_df, on='statline',rsuffix='_r')
#mtadf['exitdiff'] = mtadf['EXITS'].diff()#.replace(np.nan, '')
diff_df

# %%
mtadf.to_csv('/Users/pillbug/mtadf.csv')

# %%
diff_df.sort_values(by=['entrydiff','statline','dow'], ascending=False)

# %%
#df.sort_values(by=['userid','product'])
mtadf.sort_values(by=['entrydiff','STATION','dow'], ascending=False)

# %%
pd.value_counts(mtadf['entrydiff'].values)

# %%
pd.value_counts(mtadf['TIME'].values)

# %%
faculty_dict = {k: v.iloc[:,1:4].values.tolist() for k,v in fac.groupby("lname")}
faculty_dict

# %%
D.head()

# %%
Sdict = defaultdict(list)

for key in Ddict:
# new dict with station identifier as key and all entry/exit counts as list of values
    tmpHdict = defaultdict(list)

    for tf in Ddict[key]:
        DateTime= tf[0]
        volumn = tf[1]

        tmpHdict[DateTime.date()].append(volumn)
#        break
#        print(tmpTdict)

        ## get difference between relevant highest(latest | 8/9pm) & lowest (earliest | 4/5am) index of count of the day
    tmpCdict = defaultdict(list)
    for date in tmpHdict.keys():
#        print (date)
        #count = max(tmpTdict[date]) - min(tmpTdict[date])
        if (len(tmpHdict[date])>=2):
            count = tmpHdict[date][len(tmpHdict[date])-1] - tmpHdict[date][1]
        else:
            count = [0]

        tmpCdict[date].append(count)
    Sdict[key]= tmpCdict

# %%
print({k: Ddict[k] for k in list(Ddict.keys())[:1]})

# %%
## Count Passenger Vol by Station-Unit_SCP

Sdict = defaultdict(list)

for key in Ddict:
# new dict with station identifier as key and all entry/exit counts as list of values
    tmpHdict = defaultdict(list)

    for tf in Ddict[key]:
        DateTime= tf[0]
        #wday = tf[1]
        volume = tf[1]

        tmpHdict[DateTime.date()].append(volume)
#break
#print(tmpTdict)

        ## get difference between relevant highest(latest | 8/9pm) & lowest (earliest | 4/5am) index of count of the day
    tmpCdict = defaultdict(list)
    for date in tmpHdict.keys():
#        print (date)
        #count = max(tmpTdict[date]) - min(tmpTdict[date])
        if (len(tmpHdict[date])>=2):
            count = tmpHdict[date][len(tmpHdict[date])-1] - tmpHdict[date][1]
        else:
            count = [0]

        # tmpCdict[date].append([date.weekday(),count])
        tmpCdict[date.weekday()].append(count)
    Sdict[key]= tmpCdict


#Sdict


## Cluster Count Passenger Vol by Station

DC = {(keys[0],keys[1],keys[3]): values for keys, values in Sdict.items() }


#pd.DataFrame(Sdict[list(Sdict.keys())[0]])
#pd.DataFrame(Sdict[list(Sdict.keys())[1]])
#pd.concat([])

# %%
{k: DC[k] for k in list(DC.keys())[:10]}
