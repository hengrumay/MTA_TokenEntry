# %%
import matplotlib
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#x = [x**2 for x in range(1,100)]
#y = range(1, 100)

# %%
#plt.plot(x, y, 'ro')
#plt.show()

# %%
week1 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160409.txt")
week2 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160416.txt")
week3 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160423.txt")
week4 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160430.txt")
week5 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160507.txt")
week6 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160514.txt")
week7 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160521.txt")
week8 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160528.txt")
week9 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160604.txt")
#mtadf = pd.concat([week1, week2, week3, week4, week5, week6, week7, week8, week9], )

# %%
week1['week_flg'] = 1
week2['week_flg'] = 2
week3['week_flg'] = 3
week4['week_flg'] = 4
week5['week_flg'] = 5
week6['week_flg'] = 6
week7['week_flg'] = 7
week8['week_flg'] = 8

# %%
mtadf = pd.concat([week1, week2, week3, week4, week5, week6, week6, week7, week8], ignore_index=True)
len(mtadf)
# Out:
# 1747742

# %%
mtadf.shape
# Out:
# (1747742, 14)

# %%
#week1 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160409.txt")
#week2 = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160416.txt")

# %%
mtadf.dtypes
# Out:
# C/A                  object
# UNIT                 object
# SCP                  object
# STATION              object
# LINENAME             object
# DATE         datetime64[ns]
# TIME                 object
# ENTRIES               int64
# EXITS                 int64
# week_flg              int64
# date_time    datetime64[ns]
# statline             object
# dow                   int64
# entrydiff           float64
# dtype: object

# %%
#mtadf = pd.read_csv("http://web.mta.info/developers/data/nyct/turnstile/turnstile_160409.txt")
mtadf = mtadf.rename(columns=lambda x: x.strip())#stripping trailing/leading blanks

# %%
mtadf['date_time'] =pd.to_datetime(mtadf['DATE'] + ' ' + mtadf['TIME'],format="%m/%d/%Y %H:%M:%S")
mtadf['DATE'] = pd.to_datetime(mtadf['DATE'], format="%m/%d/%Y")

# %%
mtadf['statline'] = mtadf['STATION'] + ' ' +mtadf['LINENAME']
mtadf = mtadf.drop(axis=1, labels = ['DIVISION', 'DESC']) #drop columns to create df with only degrees
mtadf.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME       DATE      TIME  ENTRIES  \
# 0  A002  R051  02-00-00   59 ST   NQR456 2016-04-02  00:00:00  5600838
# 1  A002  R051  02-00-00   59 ST   NQR456 2016-04-02  04:00:00  5600863
# 2  A002  R051  02-00-00   59 ST   NQR456 2016-04-02  08:00:00  5600877
# 3  A002  R051  02-00-00   59 ST   NQR456 2016-04-02  12:00:00  5600922
# 4  A002  R051  02-00-00   59 ST   NQR456 2016-04-02  16:00:00  5601172
#
#      EXITS  week_flg           date_time      statline
# 0  1896290         1 2016-04-02 00:00:00  59 ST NQR456
# 1  1896293         1 2016-04-02 04:00:00  59 ST NQR456
# 2  1896313         1 2016-04-02 08:00:00  59 ST NQR456
# 3  1896375         1 2016-04-02 12:00:00  59 ST NQR456
# 4  1896445         1 2016-04-02 16:00:00  59 ST NQR456

# %%
mtadf['dow'] = mtadf['DATE'].apply(datetime.weekday) #have to use apply to iterate over series

# %%
#mtadf.head(1000)

# %%
mtadf= mtadf.sort_values(by=['statline','C/A','UNIT','SCP','date_time'])
mtadf
# Out:
#           C/A  UNIT       SCP    STATION LINENAME       DATE      TIME  \
# 29557    H007  R248  00-00-00       1 AV        L 2016-04-02  00:00:00
# 29558    H007  R248  00-00-00       1 AV        L 2016-04-02  04:00:00
# 29559    H007  R248  00-00-00       1 AV        L 2016-04-02  08:00:00
# 29560    H007  R248  00-00-00       1 AV        L 2016-04-02  12:00:00
# 29561    H007  R248  00-00-00       1 AV        L 2016-04-02  16:00:00
# 29562    H007  R248  00-00-00       1 AV        L 2016-04-02  20:00:00
# 29563    H007  R248  00-00-00       1 AV        L 2016-04-03  00:00:00
# 29564    H007  R248  00-00-00       1 AV        L 2016-04-03  04:00:00
# 29565    H007  R248  00-00-00       1 AV        L 2016-04-03  08:00:00
# 29566    H007  R248  00-00-00       1 AV        L 2016-04-03  12:00:00
# 29567    H007  R248  00-00-00       1 AV        L 2016-04-03  16:00:00
# 29568    H007  R248  00-00-00       1 AV        L 2016-04-03  20:00:00
# 29569    H007  R248  00-00-00       1 AV        L 2016-04-04  00:00:00
# 29570    H007  R248  00-00-00       1 AV        L 2016-04-04  04:00:00
# 29571    H007  R248  00-00-00       1 AV        L 2016-04-04  08:00:00
# 29572    H007  R248  00-00-00       1 AV        L 2016-04-04  12:00:00
# 29573    H007  R248  00-00-00       1 AV        L 2016-04-04  16:00:00
# 29574    H007  R248  00-00-00       1 AV        L 2016-04-04  20:00:00
# 29575    H007  R248  00-00-00       1 AV        L 2016-04-05  00:00:00
# 29576    H007  R248  00-00-00       1 AV        L 2016-04-05  04:00:00
# 29577    H007  R248  00-00-00       1 AV        L 2016-04-05  08:00:00
# 29578    H007  R248  00-00-00       1 AV        L 2016-04-05  12:00:00
# 29579    H007  R248  00-00-00       1 AV        L 2016-04-05  16:00:00
# 29580    H007  R248  00-00-00       1 AV        L 2016-04-05  20:00:00
# 29581    H007  R248  00-00-00       1 AV        L 2016-04-06  00:00:00
# 29582    H007  R248  00-00-00       1 AV        L 2016-04-06  04:00:00
# 29583    H007  R248  00-00-00       1 AV        L 2016-04-06  08:00:00
# 29584    H007  R248  00-00-00       1 AV        L 2016-04-06  12:00:00
# 29585    H007  R248  00-00-00       1 AV        L 2016-04-06  16:00:00
# 29586    H007  R248  00-00-00       1 AV        L 2016-04-06  20:00:00
# ...       ...   ...       ...        ...      ...        ...       ...
# 1723933  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  01:00:00
# 1723934  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  05:00:00
# 1723935  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  09:00:00
# 1723936  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  13:00:00
# 1723937  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  17:00:00
# 1723938  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  21:00:00
# 1723939  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  01:00:00
# 1723940  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  05:00:00
# 1723941  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  09:00:00
# 1723942  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  13:00:00
# 1723943  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  17:00:00
# 1723944  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  21:00:00
# 1723945  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  01:00:00
# 1723946  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  05:00:00
# 1723947  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  09:00:00
# 1723948  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  13:00:00
# 1723949  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  17:00:00
# 1723950  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  21:00:00
# 1723951  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  01:00:00
# 1723952  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  05:00:00
# 1723953  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  09:00:00
# 1723954  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  13:00:00
# 1723955  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  17:00:00
# 1723956  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  21:00:00
# 1723957  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  01:00:00
# 1723958  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  05:00:00
# 1723959  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  09:00:00
# 1723960  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  13:00:00
# 1723961  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  17:00:00
# 1723962  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  21:00:00
#
#           ENTRIES     EXITS  week_flg           date_time     statline  dow
# 29557    10910340  11896537         1 2016-04-02 00:00:00       1 AV L    5
# 29558    10910536  11896872         1 2016-04-02 04:00:00       1 AV L    5
# 29559    10910654  11897125         1 2016-04-02 08:00:00       1 AV L    5
# 29560    10911292  11897807         1 2016-04-02 12:00:00       1 AV L    5
# 29561    10912096  11898778         1 2016-04-02 16:00:00       1 AV L    5
# 29562    10912912  11899944         1 2016-04-02 20:00:00       1 AV L    5
# 29563    10913494  11900805         1 2016-04-03 00:00:00       1 AV L    6
# 29564    10913732  11901247         1 2016-04-03 04:00:00       1 AV L    6
# 29565    10913817  11901410         1 2016-04-03 08:00:00       1 AV L    6
# 29566    10914295  11902028         1 2016-04-03 12:00:00       1 AV L    6
# 29567    10915128  11902855         1 2016-04-03 16:00:00       1 AV L    6
# 29568    10915771  11903685         1 2016-04-03 20:00:00       1 AV L    6
# 29569    10916156  11904154         1 2016-04-04 00:00:00       1 AV L    0
# 29570    10916191  11904238         1 2016-04-04 04:00:00       1 AV L    0
# 29571    10916636  11905089         1 2016-04-04 08:00:00       1 AV L    0
# 29572    10917496  11906884         1 2016-04-04 12:00:00       1 AV L    0
# 29573    10918510  11907497         1 2016-04-04 16:00:00       1 AV L    0
# 29574    10919573  11907975         1 2016-04-04 20:00:00       1 AV L    0
# 29575    10919987  11908439         1 2016-04-05 00:00:00       1 AV L    1
# 29576    10920027  11908512         1 2016-04-05 04:00:00       1 AV L    1
# 29577    10920514  11909444         1 2016-04-05 08:00:00       1 AV L    1
# 29578    10922113  11910601         1 2016-04-05 12:00:00       1 AV L    1
# 29579    10923427  11911305         1 2016-04-05 16:00:00       1 AV L    1
# 29580    10924439  11911990         1 2016-04-05 20:00:00       1 AV L    1
# 29581    10924897  11912503         1 2016-04-06 00:00:00       1 AV L    2
# 29582    10924957  11912591         1 2016-04-06 04:00:00       1 AV L    2
# 29583    10925391  11913467         1 2016-04-06 08:00:00       1 AV L    2
# 29584    10926754  11914842         1 2016-04-06 12:00:00       1 AV L    2
# 29585    10927774  11915692         1 2016-04-06 16:00:00       1 AV L    2
# 29586    10929091  11916609         1 2016-04-06 20:00:00       1 AV L    2
# ...           ...       ...       ...                 ...          ...  ...
# 1723933        39        34         8 2016-05-23 01:00:00  ZEREGA AV 6    0
# 1723934        39        34         8 2016-05-23 05:00:00  ZEREGA AV 6    0
# 1723935        39        34         8 2016-05-23 09:00:00  ZEREGA AV 6    0
# 1723936        39        34         8 2016-05-23 13:00:00  ZEREGA AV 6    0
# 1723937        39        34         8 2016-05-23 17:00:00  ZEREGA AV 6    0
# 1723938        39        34         8 2016-05-23 21:00:00  ZEREGA AV 6    0
# 1723939        39        34         8 2016-05-24 01:00:00  ZEREGA AV 6    1
# 1723940        39        34         8 2016-05-24 05:00:00  ZEREGA AV 6    1
# 1723941        39        34         8 2016-05-24 09:00:00  ZEREGA AV 6    1
# 1723942        39        34         8 2016-05-24 13:00:00  ZEREGA AV 6    1
# 1723943        39        34         8 2016-05-24 17:00:00  ZEREGA AV 6    1
# 1723944        39        34         8 2016-05-24 21:00:00  ZEREGA AV 6    1
# 1723945        39        34         8 2016-05-25 01:00:00  ZEREGA AV 6    2
# 1723946        39        34         8 2016-05-25 05:00:00  ZEREGA AV 6    2
# 1723947        39        34         8 2016-05-25 09:00:00  ZEREGA AV 6    2
# 1723948        39        34         8 2016-05-25 13:00:00  ZEREGA AV 6    2
# 1723949        39        34         8 2016-05-25 17:00:00  ZEREGA AV 6    2
# 1723950        39        34         8 2016-05-25 21:00:00  ZEREGA AV 6    2
# 1723951        39        34         8 2016-05-26 01:00:00  ZEREGA AV 6    3
# 1723952        39        34         8 2016-05-26 05:00:00  ZEREGA AV 6    3
# 1723953        39        34         8 2016-05-26 09:00:00  ZEREGA AV 6    3
# 1723954        39        34         8 2016-05-26 13:00:00  ZEREGA AV 6    3
# 1723955        39        34         8 2016-05-26 17:00:00  ZEREGA AV 6    3
# 1723956        39        34         8 2016-05-26 21:00:00  ZEREGA AV 6    3
# 1723957        39        34         8 2016-05-27 01:00:00  ZEREGA AV 6    4
# 1723958        39        34         8 2016-05-27 05:00:00  ZEREGA AV 6    4
# 1723959        39        34         8 2016-05-27 09:00:00  ZEREGA AV 6    4
# 1723960        39        34         8 2016-05-27 13:00:00  ZEREGA AV 6    4
# 1723961        39        34         8 2016-05-27 17:00:00  ZEREGA AV 6    4
# 1723962        39        34         8 2016-05-27 21:00:00  ZEREGA AV 6    4
#
# [1747742 rows x 13 columns]

# %%
mtadf['entrydiff'] = mtadf.groupby(by=[('statline')])['ENTRIES'].diff()
mtadf
# Out:
#           C/A  UNIT       SCP    STATION LINENAME       DATE      TIME  \
# 29557    H007  R248  00-00-00       1 AV        L 2016-04-02  00:00:00
# 29558    H007  R248  00-00-00       1 AV        L 2016-04-02  04:00:00
# 29559    H007  R248  00-00-00       1 AV        L 2016-04-02  08:00:00
# 29560    H007  R248  00-00-00       1 AV        L 2016-04-02  12:00:00
# 29561    H007  R248  00-00-00       1 AV        L 2016-04-02  16:00:00
# 29562    H007  R248  00-00-00       1 AV        L 2016-04-02  20:00:00
# 29563    H007  R248  00-00-00       1 AV        L 2016-04-03  00:00:00
# 29564    H007  R248  00-00-00       1 AV        L 2016-04-03  04:00:00
# 29565    H007  R248  00-00-00       1 AV        L 2016-04-03  08:00:00
# 29566    H007  R248  00-00-00       1 AV        L 2016-04-03  12:00:00
# 29567    H007  R248  00-00-00       1 AV        L 2016-04-03  16:00:00
# 29568    H007  R248  00-00-00       1 AV        L 2016-04-03  20:00:00
# 29569    H007  R248  00-00-00       1 AV        L 2016-04-04  00:00:00
# 29570    H007  R248  00-00-00       1 AV        L 2016-04-04  04:00:00
# 29571    H007  R248  00-00-00       1 AV        L 2016-04-04  08:00:00
# 29572    H007  R248  00-00-00       1 AV        L 2016-04-04  12:00:00
# 29573    H007  R248  00-00-00       1 AV        L 2016-04-04  16:00:00
# 29574    H007  R248  00-00-00       1 AV        L 2016-04-04  20:00:00
# 29575    H007  R248  00-00-00       1 AV        L 2016-04-05  00:00:00
# 29576    H007  R248  00-00-00       1 AV        L 2016-04-05  04:00:00
# 29577    H007  R248  00-00-00       1 AV        L 2016-04-05  08:00:00
# 29578    H007  R248  00-00-00       1 AV        L 2016-04-05  12:00:00
# 29579    H007  R248  00-00-00       1 AV        L 2016-04-05  16:00:00
# 29580    H007  R248  00-00-00       1 AV        L 2016-04-05  20:00:00
# 29581    H007  R248  00-00-00       1 AV        L 2016-04-06  00:00:00
# 29582    H007  R248  00-00-00       1 AV        L 2016-04-06  04:00:00
# 29583    H007  R248  00-00-00       1 AV        L 2016-04-06  08:00:00
# 29584    H007  R248  00-00-00       1 AV        L 2016-04-06  12:00:00
# 29585    H007  R248  00-00-00       1 AV        L 2016-04-06  16:00:00
# 29586    H007  R248  00-00-00       1 AV        L 2016-04-06  20:00:00
# ...       ...   ...       ...        ...      ...        ...       ...
# 1723933  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  01:00:00
# 1723934  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  05:00:00
# 1723935  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  09:00:00
# 1723936  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  13:00:00
# 1723937  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  17:00:00
# 1723938  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  21:00:00
# 1723939  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  01:00:00
# 1723940  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  05:00:00
# 1723941  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  09:00:00
# 1723942  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  13:00:00
# 1723943  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  17:00:00
# 1723944  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  21:00:00
# 1723945  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  01:00:00
# 1723946  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  05:00:00
# 1723947  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  09:00:00
# 1723948  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  13:00:00
# 1723949  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  17:00:00
# 1723950  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  21:00:00
# 1723951  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  01:00:00
# 1723952  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  05:00:00
# 1723953  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  09:00:00
# 1723954  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  13:00:00
# 1723955  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  17:00:00
# 1723956  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  21:00:00
# 1723957  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  01:00:00
# 1723958  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  05:00:00
# 1723959  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  09:00:00
# 1723960  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  13:00:00
# 1723961  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  17:00:00
# 1723962  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  21:00:00
#
#           ENTRIES     EXITS  week_flg           date_time     statline  dow  \
# 29557    10910340  11896537         1 2016-04-02 00:00:00       1 AV L    5
# 29558    10910536  11896872         1 2016-04-02 04:00:00       1 AV L    5
# 29559    10910654  11897125         1 2016-04-02 08:00:00       1 AV L    5
# 29560    10911292  11897807         1 2016-04-02 12:00:00       1 AV L    5
# 29561    10912096  11898778         1 2016-04-02 16:00:00       1 AV L    5
# 29562    10912912  11899944         1 2016-04-02 20:00:00       1 AV L    5
# 29563    10913494  11900805         1 2016-04-03 00:00:00       1 AV L    6
# 29564    10913732  11901247         1 2016-04-03 04:00:00       1 AV L    6
# 29565    10913817  11901410         1 2016-04-03 08:00:00       1 AV L    6
# 29566    10914295  11902028         1 2016-04-03 12:00:00       1 AV L    6
# 29567    10915128  11902855         1 2016-04-03 16:00:00       1 AV L    6
# 29568    10915771  11903685         1 2016-04-03 20:00:00       1 AV L    6
# 29569    10916156  11904154         1 2016-04-04 00:00:00       1 AV L    0
# 29570    10916191  11904238         1 2016-04-04 04:00:00       1 AV L    0
# 29571    10916636  11905089         1 2016-04-04 08:00:00       1 AV L    0
# 29572    10917496  11906884         1 2016-04-04 12:00:00       1 AV L    0
# 29573    10918510  11907497         1 2016-04-04 16:00:00       1 AV L    0
# 29574    10919573  11907975         1 2016-04-04 20:00:00       1 AV L    0
# 29575    10919987  11908439         1 2016-04-05 00:00:00       1 AV L    1
# 29576    10920027  11908512         1 2016-04-05 04:00:00       1 AV L    1
# 29577    10920514  11909444         1 2016-04-05 08:00:00       1 AV L    1
# 29578    10922113  11910601         1 2016-04-05 12:00:00       1 AV L    1
# 29579    10923427  11911305         1 2016-04-05 16:00:00       1 AV L    1
# 29580    10924439  11911990         1 2016-04-05 20:00:00       1 AV L    1
# 29581    10924897  11912503         1 2016-04-06 00:00:00       1 AV L    2
# 29582    10924957  11912591         1 2016-04-06 04:00:00       1 AV L    2
# 29583    10925391  11913467         1 2016-04-06 08:00:00       1 AV L    2
# 29584    10926754  11914842         1 2016-04-06 12:00:00       1 AV L    2
# 29585    10927774  11915692         1 2016-04-06 16:00:00       1 AV L    2
# 29586    10929091  11916609         1 2016-04-06 20:00:00       1 AV L    2
# ...           ...       ...       ...                 ...          ...  ...
# 1723933        39        34         8 2016-05-23 01:00:00  ZEREGA AV 6    0
# 1723934        39        34         8 2016-05-23 05:00:00  ZEREGA AV 6    0
# 1723935        39        34         8 2016-05-23 09:00:00  ZEREGA AV 6    0
# 1723936        39        34         8 2016-05-23 13:00:00  ZEREGA AV 6    0
# 1723937        39        34         8 2016-05-23 17:00:00  ZEREGA AV 6    0
# 1723938        39        34         8 2016-05-23 21:00:00  ZEREGA AV 6    0
# 1723939        39        34         8 2016-05-24 01:00:00  ZEREGA AV 6    1
# 1723940        39        34         8 2016-05-24 05:00:00  ZEREGA AV 6    1
# 1723941        39        34         8 2016-05-24 09:00:00  ZEREGA AV 6    1
# 1723942        39        34         8 2016-05-24 13:00:00  ZEREGA AV 6    1
# 1723943        39        34         8 2016-05-24 17:00:00  ZEREGA AV 6    1
# 1723944        39        34         8 2016-05-24 21:00:00  ZEREGA AV 6    1
# 1723945        39        34         8 2016-05-25 01:00:00  ZEREGA AV 6    2
# 1723946        39        34         8 2016-05-25 05:00:00  ZEREGA AV 6    2
# 1723947        39        34         8 2016-05-25 09:00:00  ZEREGA AV 6    2
# 1723948        39        34         8 2016-05-25 13:00:00  ZEREGA AV 6    2
# 1723949        39        34         8 2016-05-25 17:00:00  ZEREGA AV 6    2
# 1723950        39        34         8 2016-05-25 21:00:00  ZEREGA AV 6    2
# 1723951        39        34         8 2016-05-26 01:00:00  ZEREGA AV 6    3
# 1723952        39        34         8 2016-05-26 05:00:00  ZEREGA AV 6    3
# 1723953        39        34         8 2016-05-26 09:00:00  ZEREGA AV 6    3
# 1723954        39        34         8 2016-05-26 13:00:00  ZEREGA AV 6    3
# 1723955        39        34         8 2016-05-26 17:00:00  ZEREGA AV 6    3
# 1723956        39        34         8 2016-05-26 21:00:00  ZEREGA AV 6    3
# 1723957        39        34         8 2016-05-27 01:00:00  ZEREGA AV 6    4
# 1723958        39        34         8 2016-05-27 05:00:00  ZEREGA AV 6    4
# 1723959        39        34         8 2016-05-27 09:00:00  ZEREGA AV 6    4
# 1723960        39        34         8 2016-05-27 13:00:00  ZEREGA AV 6    4
# 1723961        39        34         8 2016-05-27 17:00:00  ZEREGA AV 6    4
# 1723962        39        34         8 2016-05-27 21:00:00  ZEREGA AV 6    4
#
#          entrydiff
# 29557          NaN
# 29558        196.0
# 29559        118.0
# 29560        638.0
# 29561        804.0
# 29562        816.0
# 29563        582.0
# 29564        238.0
# 29565         85.0
# 29566        478.0
# 29567        833.0
# 29568        643.0
# 29569        385.0
# 29570         35.0
# 29571        445.0
# 29572        860.0
# 29573       1014.0
# 29574       1063.0
# 29575        414.0
# 29576         40.0
# 29577        487.0
# 29578       1599.0
# 29579       1314.0
# 29580       1012.0
# 29581        458.0
# 29582         60.0
# 29583        434.0
# 29584       1363.0
# 29585       1020.0
# 29586       1317.0
# ...            ...
# 1723933        0.0
# 1723934        0.0
# 1723935        0.0
# 1723936        0.0
# 1723937        0.0
# 1723938        0.0
# 1723939        0.0
# 1723940        0.0
# 1723941        0.0
# 1723942        0.0
# 1723943        0.0
# 1723944        0.0
# 1723945        0.0
# 1723946        0.0
# 1723947        0.0
# 1723948        0.0
# 1723949        0.0
# 1723950        0.0
# 1723951        0.0
# 1723952        0.0
# 1723953        0.0
# 1723954        0.0
# 1723955        0.0
# 1723956        0.0
# 1723957        0.0
# 1723958        0.0
# 1723959        0.0
# 1723960        0.0
# 1723961        0.0
# 1723962        0.0
#
# [1747742 rows x 14 columns]

# %%
mtadf2 =mtadf[mtadf['TIME'] != '00:00:00']

# %%
mtadf2
# Out:
#           C/A  UNIT       SCP    STATION LINENAME       DATE      TIME  \
# 29558    H007  R248  00-00-00       1 AV        L 2016-04-02  04:00:00
# 29559    H007  R248  00-00-00       1 AV        L 2016-04-02  08:00:00
# 29560    H007  R248  00-00-00       1 AV        L 2016-04-02  12:00:00
# 29561    H007  R248  00-00-00       1 AV        L 2016-04-02  16:00:00
# 29562    H007  R248  00-00-00       1 AV        L 2016-04-02  20:00:00
# 29564    H007  R248  00-00-00       1 AV        L 2016-04-03  04:00:00
# 29565    H007  R248  00-00-00       1 AV        L 2016-04-03  08:00:00
# 29566    H007  R248  00-00-00       1 AV        L 2016-04-03  12:00:00
# 29567    H007  R248  00-00-00       1 AV        L 2016-04-03  16:00:00
# 29568    H007  R248  00-00-00       1 AV        L 2016-04-03  20:00:00
# 29570    H007  R248  00-00-00       1 AV        L 2016-04-04  04:00:00
# 29571    H007  R248  00-00-00       1 AV        L 2016-04-04  08:00:00
# 29572    H007  R248  00-00-00       1 AV        L 2016-04-04  12:00:00
# 29573    H007  R248  00-00-00       1 AV        L 2016-04-04  16:00:00
# 29574    H007  R248  00-00-00       1 AV        L 2016-04-04  20:00:00
# 29576    H007  R248  00-00-00       1 AV        L 2016-04-05  04:00:00
# 29577    H007  R248  00-00-00       1 AV        L 2016-04-05  08:00:00
# 29578    H007  R248  00-00-00       1 AV        L 2016-04-05  12:00:00
# 29579    H007  R248  00-00-00       1 AV        L 2016-04-05  16:00:00
# 29580    H007  R248  00-00-00       1 AV        L 2016-04-05  20:00:00
# 29582    H007  R248  00-00-00       1 AV        L 2016-04-06  04:00:00
# 29583    H007  R248  00-00-00       1 AV        L 2016-04-06  08:00:00
# 29584    H007  R248  00-00-00       1 AV        L 2016-04-06  12:00:00
# 29585    H007  R248  00-00-00       1 AV        L 2016-04-06  16:00:00
# 29586    H007  R248  00-00-00       1 AV        L 2016-04-06  20:00:00
# 29588    H007  R248  00-00-00       1 AV        L 2016-04-07  04:00:00
# 29589    H007  R248  00-00-00       1 AV        L 2016-04-07  08:00:00
# 29590    H007  R248  00-00-00       1 AV        L 2016-04-07  12:00:00
# 29591    H007  R248  00-00-00       1 AV        L 2016-04-07  16:00:00
# 29592    H007  R248  00-00-00       1 AV        L 2016-04-07  20:00:00
# ...       ...   ...       ...        ...      ...        ...       ...
# 1723933  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  01:00:00
# 1723934  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  05:00:00
# 1723935  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  09:00:00
# 1723936  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  13:00:00
# 1723937  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  17:00:00
# 1723938  R419  R326  00-05-01  ZEREGA AV        6 2016-05-23  21:00:00
# 1723939  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  01:00:00
# 1723940  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  05:00:00
# 1723941  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  09:00:00
# 1723942  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  13:00:00
# 1723943  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  17:00:00
# 1723944  R419  R326  00-05-01  ZEREGA AV        6 2016-05-24  21:00:00
# 1723945  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  01:00:00
# 1723946  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  05:00:00
# 1723947  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  09:00:00
# 1723948  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  13:00:00
# 1723949  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  17:00:00
# 1723950  R419  R326  00-05-01  ZEREGA AV        6 2016-05-25  21:00:00
# 1723951  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  01:00:00
# 1723952  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  05:00:00
# 1723953  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  09:00:00
# 1723954  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  13:00:00
# 1723955  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  17:00:00
# 1723956  R419  R326  00-05-01  ZEREGA AV        6 2016-05-26  21:00:00
# 1723957  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  01:00:00
# 1723958  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  05:00:00
# 1723959  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  09:00:00
# 1723960  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  13:00:00
# 1723961  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  17:00:00
# 1723962  R419  R326  00-05-01  ZEREGA AV        6 2016-05-27  21:00:00
#
#           ENTRIES     EXITS  week_flg           date_time     statline  dow  \
# 29558    10910536  11896872         1 2016-04-02 04:00:00       1 AV L    5
# 29559    10910654  11897125         1 2016-04-02 08:00:00       1 AV L    5
# 29560    10911292  11897807         1 2016-04-02 12:00:00       1 AV L    5
# 29561    10912096  11898778         1 2016-04-02 16:00:00       1 AV L    5
# 29562    10912912  11899944         1 2016-04-02 20:00:00       1 AV L    5
# 29564    10913732  11901247         1 2016-04-03 04:00:00       1 AV L    6
# 29565    10913817  11901410         1 2016-04-03 08:00:00       1 AV L    6
# 29566    10914295  11902028         1 2016-04-03 12:00:00       1 AV L    6
# 29567    10915128  11902855         1 2016-04-03 16:00:00       1 AV L    6
# 29568    10915771  11903685         1 2016-04-03 20:00:00       1 AV L    6
# 29570    10916191  11904238         1 2016-04-04 04:00:00       1 AV L    0
# 29571    10916636  11905089         1 2016-04-04 08:00:00       1 AV L    0
# 29572    10917496  11906884         1 2016-04-04 12:00:00       1 AV L    0
# 29573    10918510  11907497         1 2016-04-04 16:00:00       1 AV L    0
# 29574    10919573  11907975         1 2016-04-04 20:00:00       1 AV L    0
# 29576    10920027  11908512         1 2016-04-05 04:00:00       1 AV L    1
# 29577    10920514  11909444         1 2016-04-05 08:00:00       1 AV L    1
# 29578    10922113  11910601         1 2016-04-05 12:00:00       1 AV L    1
# 29579    10923427  11911305         1 2016-04-05 16:00:00       1 AV L    1
# 29580    10924439  11911990         1 2016-04-05 20:00:00       1 AV L    1
# 29582    10924957  11912591         1 2016-04-06 04:00:00       1 AV L    2
# 29583    10925391  11913467         1 2016-04-06 08:00:00       1 AV L    2
# 29584    10926754  11914842         1 2016-04-06 12:00:00       1 AV L    2
# 29585    10927774  11915692         1 2016-04-06 16:00:00       1 AV L    2
# 29586    10929091  11916609         1 2016-04-06 20:00:00       1 AV L    2
# 29588    10929650  11917279         1 2016-04-07 04:00:00       1 AV L    3
# 29589    10930104  11918157         1 2016-04-07 08:00:00       1 AV L    3
# 29590    10931451  11919522         1 2016-04-07 12:00:00       1 AV L    3
# 29591    10932551  11920341         1 2016-04-07 16:00:00       1 AV L    3
# 29592    10933773  11921279         1 2016-04-07 20:00:00       1 AV L    3
# ...           ...       ...       ...                 ...          ...  ...
# 1723933        39        34         8 2016-05-23 01:00:00  ZEREGA AV 6    0
# 1723934        39        34         8 2016-05-23 05:00:00  ZEREGA AV 6    0
# 1723935        39        34         8 2016-05-23 09:00:00  ZEREGA AV 6    0
# 1723936        39        34         8 2016-05-23 13:00:00  ZEREGA AV 6    0
# 1723937        39        34         8 2016-05-23 17:00:00  ZEREGA AV 6    0
# 1723938        39        34         8 2016-05-23 21:00:00  ZEREGA AV 6    0
# 1723939        39        34         8 2016-05-24 01:00:00  ZEREGA AV 6    1
# 1723940        39        34         8 2016-05-24 05:00:00  ZEREGA AV 6    1
# 1723941        39        34         8 2016-05-24 09:00:00  ZEREGA AV 6    1
# 1723942        39        34         8 2016-05-24 13:00:00  ZEREGA AV 6    1
# 1723943        39        34         8 2016-05-24 17:00:00  ZEREGA AV 6    1
# 1723944        39        34         8 2016-05-24 21:00:00  ZEREGA AV 6    1
# 1723945        39        34         8 2016-05-25 01:00:00  ZEREGA AV 6    2
# 1723946        39        34         8 2016-05-25 05:00:00  ZEREGA AV 6    2
# 1723947        39        34         8 2016-05-25 09:00:00  ZEREGA AV 6    2
# 1723948        39        34         8 2016-05-25 13:00:00  ZEREGA AV 6    2
# 1723949        39        34         8 2016-05-25 17:00:00  ZEREGA AV 6    2
# 1723950        39        34         8 2016-05-25 21:00:00  ZEREGA AV 6    2
# 1723951        39        34         8 2016-05-26 01:00:00  ZEREGA AV 6    3
# 1723952        39        34         8 2016-05-26 05:00:00  ZEREGA AV 6    3
# 1723953        39        34         8 2016-05-26 09:00:00  ZEREGA AV 6    3
# 1723954        39        34         8 2016-05-26 13:00:00  ZEREGA AV 6    3
# 1723955        39        34         8 2016-05-26 17:00:00  ZEREGA AV 6    3
# 1723956        39        34         8 2016-05-26 21:00:00  ZEREGA AV 6    3
# 1723957        39        34         8 2016-05-27 01:00:00  ZEREGA AV 6    4
# 1723958        39        34         8 2016-05-27 05:00:00  ZEREGA AV 6    4
# 1723959        39        34         8 2016-05-27 09:00:00  ZEREGA AV 6    4
# 1723960        39        34         8 2016-05-27 13:00:00  ZEREGA AV 6    4
# 1723961        39        34         8 2016-05-27 17:00:00  ZEREGA AV 6    4
# 1723962        39        34         8 2016-05-27 21:00:00  ZEREGA AV 6    4
#
#          entrydiff
# 29558        196.0
# 29559        118.0
# 29560        638.0
# 29561        804.0
# 29562        816.0
# 29564        238.0
# 29565         85.0
# 29566        478.0
# 29567        833.0
# 29568        643.0
# 29570         35.0
# 29571        445.0
# 29572        860.0
# 29573       1014.0
# 29574       1063.0
# 29576         40.0
# 29577        487.0
# 29578       1599.0
# 29579       1314.0
# 29580       1012.0
# 29582         60.0
# 29583        434.0
# 29584       1363.0
# 29585       1020.0
# 29586       1317.0
# 29588         53.0
# 29589        454.0
# 29590       1347.0
# 29591       1100.0
# 29592       1222.0
# ...            ...
# 1723933        0.0
# 1723934        0.0
# 1723935        0.0
# 1723936        0.0
# 1723937        0.0
# 1723938        0.0
# 1723939        0.0
# 1723940        0.0
# 1723941        0.0
# 1723942        0.0
# 1723943        0.0
# 1723944        0.0
# 1723945        0.0
# 1723946        0.0
# 1723947        0.0
# 1723948        0.0
# 1723949        0.0
# 1723950        0.0
# 1723951        0.0
# 1723952        0.0
# 1723953        0.0
# 1723954        0.0
# 1723955        0.0
# 1723956        0.0
# 1723957        0.0
# 1723958        0.0
# 1723959        0.0
# 1723960        0.0
# 1723961        0.0
# 1723962        0.0
#
# [1597031 rows x 14 columns]

# %%
mtadf2 = mtadf2[mtadf2['entrydiff'] > 0]

# %%
mtadf2['entrydiff'].describe()
# Out:
# count    1.199416e+06
# mean     5.149224e+04
# std      7.693440e+06
# min      1.000000e+00
# 25%      2.900000e+01
# 50%      1.220000e+02
# 75%      3.170000e+02
# max      2.126577e+09
# Name: entrydiff, dtype: float64

# %%
mtadf2["entrydiff"].quantile(.999)
# Out:
# 2667.5850000001956

# %%
#mtadf2["entrydiff"].value_counts()

# %%
mtadf2 = mtadf2[mtadf2['entrydiff'] < mtadf2["entrydiff"].quantile(.999)]

# %%
len(mtadf2)
# Out:
# 1198216

# %%
len(mtadf)
# Out:
# 1747742

# %%
mtadf2['entrydiff'].describe()
# Out:
# count    1.198216e+06
# mean     2.261991e+02
# std      2.861525e+02
# min      1.000000e+00
# 25%      2.900000e+01
# 50%      1.220000e+02
# 75%      3.160000e+02
# max      2.667000e+03
# Name: entrydiff, dtype: float64

# %%
mtadf2['entrydiff'].argmin()
# Out:
# 805421

# %%
mtadf.ix[134259]
# Out:
# C/A                         R170
# UNIT                        R191
# SCP                     00-03-00
# STATION                   103 ST
# LINENAME                       1
# DATE         2016-04-07 00:00:00
# TIME                    05:00:00
# ENTRIES                  6893106
# EXITS                    3799456
# week_flg                       1
# date_time    2016-04-07 05:00:00
# statline                103 ST 1
# dow                            3
# entrydiff                      1
# Name: 134259, dtype: object

# %%
mtadf2['entrydiff'].max()
# Out:
# 2667.0

# %%
# mtadf2.nlargest(15,columns='entrydiff').plot(x= 'statline', y= 'entrydiff',kind='barh')
mtadf2.nlargest(15,columns='entrydiff').plot(kind='barh')

# %%
mtadf2.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DATE', 'TIME', 'ENTRIES',
#        'EXITS', 'week_flg', 'date_time', 'statline', 'dow', 'entrydiff'],
#       dtype='object')

# %%
mtadf3 = mtadf2.groupby(by=['statline'])['entrydiff'].sum()

# %%
mtadf3
# Out:
# statline
# 1 AV L                        1048538.0
# 103 ST 1                       661207.0
# 103 ST 6                       517652.0
# 103 ST BC                      243724.0
# 103 ST-CORONA 7                962656.0
# 104 ST A                        82014.0
# 104 ST JZ                      111009.0
# 110 ST 6                       667901.0
# 111 ST 7                       559347.0
# 111 ST A                       105795.0
# 111 ST J                       123106.0
# 116 ST 23                      641044.0
# 116 ST 6                       851854.0
# 116 ST BC                      374388.0
# 116 ST-COLUMBIA 1              780817.0
# 121 ST JZ                      115518.0
# 125 ST 1                       362489.0
# 125 ST 23                      605069.0
# 125 ST 456                    1310034.0
# 125 ST ACBD                   1353848.0
# 135 ST 23                      724448.0
# 135 ST BC                      290190.0
# 137 ST CITY COL 1              777457.0
# 138/GRAND CONC 45              158840.0
# 14 ST 123FLM                   954386.0
# 14 ST ACEL                    1008732.0
# 14 ST FLM123                   780185.0
# 14 ST-UNION SQ 456LNQR        1766589.0
# 14 ST-UNION SQ LNQR456        3711978.0
# 145 ST 1                       457925.0
#                                 ...
# THIRTY THIRD ST 1             1116981.0
# TIMES SQ-42 ST 1237ACENQRS    3354597.0
# TIMES SQ-42 ST ACENQRS1237     517701.0
# TOMPKINSVILLE 1                 39431.0
# TREMONT AV BD                  511714.0
# TWENTY THIRD ST 1              436962.0
# UNION ST R                     287131.0
# UTICA AV AC                    821127.0
# V.CORTLANDT PK 1               331954.0
# VAN SICLEN AV 3                234733.0
# VAN SICLEN AV JZ               156220.0
# VAN SICLEN AVE C               164844.0
# VERNON-JACKSON 7               679259.0
# W 4 ST-WASH SQ ABCDEFM        2311829.0
# W 8 ST-AQUARIUM FQ             110293.0
# WAKEFIELD/241 2                271281.0
# WALL ST 23                    1167549.0
# WALL ST 45                    1001786.0
# WEST FARMS SQ 25               399393.0
# WESTCHESTER SQ 6               275386.0
# WHITEHALL S-FRY R1             834819.0
# WHITLOCK AV 6                   85081.0
# WILSON AV L                     49720.0
# WINTHROP ST 25                 340641.0
# WOODHAVEN BLVD JZ              224010.0
# WOODHAVEN BLVD MR             1109617.0
# WOODLAWN 4                     352601.0
# WORLD TRADE CTR ACE23          686721.0
# YORK ST F                      532276.0
# ZEREGA AV 6                    118321.0
# Name: entrydiff, dtype: float64

# %%
# mtadf3.plot?

# %%
# mtadf3a = mtadf3.nlargest(15)
# mtadf3a.sort_values(ascending=True).plot(kind='barh')

# %%
plt.figure(figsize=(15,8))
mtadf3.nlargest(15).sort_values(ascending=True).plot(kind='barh', grid=False)
plt.xlabel("Entries")
plt.ylabel("Station-Line")
plt.title("Total Entries of Top 15 Stations Across April-May 2016",fontsize=25, fontweight='bold')
ax.legend()
plt.show()
sns.set_style('dark')
sns.set(font_scale=1)

# %%
Station Names   Flow    Count of Entrances  Flow/Entrances
34 ST-HERALD SQ BDFMNQR         5035010 11  457,728.18
GRD CNTRL-42 ST 4567S           6384809 15  425,653.93
42 ST-PORT AUTH ACENQRS1237     3674337 9   408,259.67
W 4 ST-WASH SQ ABCDEFM          2311829 6   385,304.83
14 ST-UNION SQ LNQR456          3711978 10  371,197.80
86 ST 456                       2894762 8   361,845.25
JKSN HT-ROOSVLT EFMR7           2403158 7   343,308.29
FLUSHING-MAIN 7                 2778742 10  277,874.20
TIMES SQ-42 ST 1237ACENQRS      3354597 13  258,045.92
34 ST-PENN STA ACE              3538270 16  221,141.88
59 ST COLUMBUS ABCD1            2379059 12  198,254.92
CANAL ST JNQRZ6                 2346221 14  167,587.21
34 ST-PENN STA 123ACE           2647402 16  165,462.63
59 ST 456NQR                    2145341 13  165,026.23
47-50 STS ROCK BDFM             2422287 17  142,487.47

# %%
mtadf4 = mtadf2.groupby(by=['statline','dow'])['entrydiff'].sum().reset_index()

# %%
# mtadf4

# %%
test= mtadf3.nlargest(15)
test=test.to_frame()
test.columns
# Out:
# Index(['entrydiff'], dtype='object')

# %%
mtadf3.nlargest(15)
# Out:
# statline
# GRD CNTRL-42 ST 4567S          6384809.0
# 34 ST-HERALD SQ BDFMNQR        5035010.0
# 14 ST-UNION SQ LNQR456         3711978.0
# 42 ST-PORT AUTH ACENQRS1237    3674337.0
# 34 ST-PENN STA ACE             3538270.0
# TIMES SQ-42 ST 1237ACENQRS     3354597.0
# 86 ST 456                      2894762.0
# FLUSHING-MAIN 7                2778742.0
# 34 ST-PENN STA 123ACE          2647402.0
# 47-50 STS ROCK BDFM            2422287.0
# JKSN HT-ROOSVLT EFMR7          2403158.0
# 59 ST COLUMBUS ABCD1           2379059.0
# CANAL ST JNQRZ6                2346221.0
# W 4 ST-WASH SQ ABCDEFM         2311829.0
# 59 ST 456NQR                   2145341.0
# Name: entrydiff, dtype: float64

# %%
ax.legend?

# %%
fig,ax = plt.subplots(figsize=(15,10))

sns.set_style("dark")

#stations = ["GRD CNTRL-42 ST 4567S", "34 ST-HERALD SQ BDFMNQR",'14 ST-UNION SQ LNQR456','42 ST-PORT AUTH ACENQRS1237','JKSN HT-ROOSVLT EFMR7'] #mtadf3.nlargest(15)
stations = mtadf3.nlargest(15).axes
print(stations[0])

my_xticks = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']

for temp in stations[0]:
    dat = mtadf4[mtadf4['statline'] == temp]
    #print((dat["dow"]))
    #print(mtadf4["entrydiff"])
    plt.xticks(dat["dow"],my_xticks, rotation=45,fontsize=20, fontweight='bold')
    ax.plot(dat["dow"], dat["entrydiff"], label = "Station: {0}".format(temp))

plt.title("Entries By Day of Week for Top 15 Station-Lines",fontsize=30, fontweight='bold')#, grid=False)
plt.xlabel("Day Of Week",fontsize=30, fontweight='bold')
plt.ylabel("Entry",fontsize=30, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize=15)
plt.show()
sns.set(font_scale=3)
# Out:
# Index(['GRD CNTRL-42 ST 4567S', '34 ST-HERALD SQ BDFMNQR',
#        '14 ST-UNION SQ LNQR456', '42 ST-PORT AUTH ACENQRS1237',
#        '34 ST-PENN STA ACE', 'TIMES SQ-42 ST 1237ACENQRS', '86 ST 456',
#        'FLUSHING-MAIN 7', '34 ST-PENN STA 123ACE', '47-50 STS ROCK BDFM',
#        'JKSN HT-ROOSVLT EFMR7', '59 ST COLUMBUS ABCD1', 'CANAL ST JNQRZ6',
#        'W 4 ST-WASH SQ ABCDEFM', '59 ST 456NQR'],
#       dtype='object', name='statline')

# %%
mtadf5 = mtadf2.groupby(by=['statline','TIME','dow'])['entrydiff'].sum().reset_index()

# %%
mtadf5["TIME"] = mtadf5["TIME"].apply(lambda x: int(x[:2]))

# %%
mtadf5 = mtadf5[mtadf5['dow'] < 5]

# %%
mtadf5 = mtadf5.groupby(by=['statline','TIME'])['entrydiff'].sum().reset_index()

# %%
ax.set_xticks?

# %%
import matplotlib.cm as cm

fig,ax = plt.subplots(figsize=(20,10))
sns.set_style('dark')

#stations = ["GRD CNTRL-42 ST 4567S", "34 ST-HERALD SQ BDFMNQR",'14 ST-UNION SQ LNQR456','42 ST-PORT AUTH ACENQRS1237','JKSN HT-ROOSVLT EFMR7'] #mtadf3.nlargest(15)
stations = mtadf3.nlargest(15).axes
colors = iter(cm.rainbow(np.linspace(0, 1, len(stations[0]))))
print(stations[0])
#print(type(stations))
for temp in stations[0]:
    dat = mtadf5[mtadf5['statline'] == temp]
    #print((dat["dow"]))
    #print(mtadf4["entrydiff"])
    ax.plot(dat["TIME"], dat["entrydiff"], 'bo-',label = "Station: {0}".format(temp),color=next(colors))#,gride=False)
    ax.set_xlim([0,24])
    ax.set_xticks(np.arange(1,25))

plt.title('Entries by Hour of Day for Top 15 Station-Lines',fontsize=30, fontweight='bold')
plt.xlabel("Time of Day (hr)",fontsize=20, fontweight='bold')
plt.ylabel("Entry",fontsize=20, fontweight='bold')
ax.legend(loc="best")
plt.show()

sns.set(font_scale=2)
# Out:
# Index(['GRD CNTRL-42 ST 4567S', '34 ST-HERALD SQ BDFMNQR',
#        '14 ST-UNION SQ LNQR456', '42 ST-PORT AUTH ACENQRS1237',
#        '34 ST-PENN STA ACE', 'TIMES SQ-42 ST 1237ACENQRS', '86 ST 456',
#        'FLUSHING-MAIN 7', '34 ST-PENN STA 123ACE', '47-50 STS ROCK BDFM',
#        'JKSN HT-ROOSVLT EFMR7', '59 ST COLUMBUS ABCD1', 'CANAL ST JNQRZ6',
#        'W 4 ST-WASH SQ ABCDEFM', '59 ST 456NQR'],
#       dtype='object', name='statline')

# %%
plt.figure(figsize=(15,7))
# plt.figure()
# StatFlowDF2.nlargest(15).plot(kind='bar')
#df = StatFlowDS.sort_values(ascending=False)
ax = mtadf2.iloc[:11].plot(kind="barh")
ax.invert_yaxis()

# %%
StatFlowDS = pd.Series(mtadf2[['statline','entrydiff']], name = 'DateValue')
# StatFlowDF2.to_csv('StatFlowDF2.csv')

# %%
diff_df['sumentry'] = mtadf.groupby(by=['statline', 'date_time','dow','TIME']).sum().reset_index()

#df.groupby('userid').sum()
#diff_df.rename(columns = {'ENTRIES':'entrydiff', 'EXITS' :'exitdiff'}, inplace = True)
#print(len(diff_df))

# %%
#pd.value_counts(mtadf['UNIT'].values)
len(diff_df)

# %%
mtadf.dtypes
# Out:
# C/A                  object
# UNIT                 object
# SCP                  object
# STATION              object
# LINENAME             object
# DATE         datetime64[ns]
# TIME                 object
# ENTRIES               int64
# EXITS                 int64
# week_flg              int64
# date_time    datetime64[ns]
# statline             object
# dow                   int64
# entrydiff           float64
# dtype: object
